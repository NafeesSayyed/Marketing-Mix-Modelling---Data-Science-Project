# %% [markdown]
# <a href="https://colab.research.google.com/github/NafeesSayyed/Marketing-Mix-Modelling---Data-Science-Project/blob/main/mmm_xgboost_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mmm_processed_dataset.csv')

# %%
df
# Out:
#          week_sin  week_cos  holiday sales_promotion  competitor_spend  \
# 0    6.631227e-01  0.748511        0         Coupons          318300.0
# 1    7.485107e-01  0.663123        0         Coupons          316400.0
# 2    8.229839e-01  0.568065        0         Coupons          280950.0
# 3    8.854560e-01  0.464723        0          Normal          311100.0
# 4    9.350162e-01  0.354605        0          Normal          256600.0
# ..            ...       ...      ...             ...               ...
# 196 -3.546049e-01  0.935016        0            BOGO          252250.0
# 197 -2.393157e-01  0.970942        0         Coupons          344050.0
# 198 -1.205367e-01  0.992709        0         Coupons          291550.0
# 199  6.430000e-16  1.000000        0          Normal          265650.0
# 200  1.205367e-01  0.992709        0          Normal          354750.0
#
#      instagram_spend  google_ads_spend     tv_spend  youtube_spend  \
# 0        19352.28252      17255.978570  17296.65907    17335.03836
# 1        19519.23078      13445.311650  17961.49303    17474.43370
# 2        20251.35058      18254.775650  18275.03899    18046.31235
# 3        20282.68126      20665.335790  17762.93864    17575.31642
# 4        15965.33864      19764.674640  16933.77281    16334.81682
# ..               ...               ...          ...            ...
# 196      19136.40416      17516.154490  15906.14190    17997.75345
# 197      20161.57727      13661.157220  18026.04257    17841.79001
# 198      21290.61638      10480.513450  18521.97568    16126.48350
# 199      20530.81473       7890.597435  17847.37146    17093.05937
# 200      19916.98488       5813.328925  18229.85237    16595.83642
#
#      newspaper_spend  influencer_spend    ott_spend    sales
# 0        6825.645242      12357.741070  12471.81155  2487650
# 1        7187.119487       9414.812346  15731.39330  2679131
# 2        7726.462029       7031.803656  17097.82381  2748338
# 3        8680.294811       5132.776373  16333.91503  2683154
# 4        6443.062410       9561.223919  17592.96391  2584839
# ..               ...               ...          ...      ...
# 196      6399.177780      13515.271560  18481.27306  2824619
# 197      7440.142266      15329.405610  19243.36801  2747119
# 198      7811.002283      15077.752050  19836.02606  2676494
# 199      8648.426478      15340.738680  18908.60835  2489367
# 200      8067.795002      15416.967670  18615.12452  2299871
#
# [201 rows x 13 columns]

# %%
X = df.drop('sales', axis = 1)
y = df['sales']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
split = int(len(df) * 0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
import xgboost as xgb
regressor = xgb.XGBRegressor(n_estimators=10, max_depth = 1, learning_rate=1.5, reg_lambda=2.26, random_state=42)
regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=1.5, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=1,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=10,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.to_numpy().reshape(len(y_test), 1)), 1))
# Out:
# [[2633758.   2616604.  ]
#  [2633758.   2563774.  ]
#  [2175278.5  2309863.  ]
#  [2099636.25 2180514.  ]
#  [2175278.5  2058161.  ]
#  [2099636.25 1906430.  ]
#  [2175278.5  2603953.  ]
#  [2623822.   2639995.  ]
#  [2623822.   2621384.  ]
#  [2623822.   2655601.  ]
#  [2558115.75 2783100.  ]
#  [2813547.5  2567493.  ]
#  [2186585.5  2372824.  ]
#  [2186585.5  2192540.  ]
#  [2186585.5  2163927.  ]
#  [2376377.25 2539843.  ]
#  [2380260.25 2574071.  ]
#  [2380260.25 2481141.  ]
#  [2455902.5  2342117.  ]
#  [2380260.25 2479184.  ]
#  [2453953.5  2205311.  ]
#  [2008729.88 2034506.  ]
#  [1826991.25 1851341.  ]
#  [1655188.75 1803401.  ]
#  [1556303.5  1597048.  ]
#  [1556303.5  1513716.  ]
#  [1374564.88 1444750.  ]
#  [1374564.88 1282763.  ]
#  [1749415.12 1772506.  ]
#  [1749415.12 1686361.  ]
#  [1300871.88 1625483.  ]
#  [1749415.12 1602643.  ]
#  [2376377.25 2414361.  ]
#  [2558115.75 2535608.  ]
#  [2548179.75 2502857.  ]
#  [2805560.5  2624574.  ]
#  [2985350.   2824619.  ]
#  [2985350.   2747119.  ]
#  [2358388.   2676494.  ]
#  [2358388.   2489367.  ]
#  [2358388.   2299871.  ]]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R^2: {r2 * 100:.2f}%")
# Out:
# R^2: 86.21%

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f"MAPE: {mape * 100:.2f}%")
# Out:
# MAPE: 5.36%
